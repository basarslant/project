# %%
import pandas as pd

# %%
data=pd.read_csv("bank-additional.csv",sep=",")

# %%
data
# Out:
#       age            job   marital            education  default  housing  \
# 0      45   entrepreneur   married    university.degree  unknown      yes
# 1      29     technician    single    university.degree       no      yes
# 2      40     management   married          high.school       no       no
# 3      38     technician   married  professional.course       no      yes
# 4      34         admin.   married    university.degree       no       no
# 5      48     technician   married    university.degree       no       no
# 6      44       services   married  professional.course       no       no
# 7      39     management   married          high.school       no       no
# 8      31         admin.   married    university.degree       no      yes
# 9      31     technician    single          high.school       no      yes
# 10     31         admin.   married    university.degree       no      yes
# 11     32     technician    single    university.degree       no       no
# ...
